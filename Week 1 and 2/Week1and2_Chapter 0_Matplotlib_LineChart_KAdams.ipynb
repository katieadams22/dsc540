# %%
# Create a line chart with Matplotlib and the following data file

import pandas as pd
import matplotlib.pyplot as plt

var = pd.read_excel('C:\\Users\\kadams\\Downloads\\world-population.xlsm')
var.head()
# Out:
#    Year  Population
# 0  1960  3028654024
# 1  1961  3068356747
# 2  1962  3121963107
# 3  1963  3187471383
# 4  1964  3253112403

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

dataframe = pd.read_excel('C:\\Users\\kadams\\Downloads\\world-population.xlsm')

x = dataframe.Year
y = dataframe.Population

stats = linregress(x, y)

m = stats.slope
b = stats.intercept

# Change the default figure size
plt.figure(figsize=(10,10))

# Change the default marker for the scatter from circles to x's
plt.scatter(x, y, marker='x')

# Set the linewidth on the regression line to 3px
plt.plot(x, m * x + b, color="red", linewidth=3)

# Add x and y lables, and set their font size
plt.xlabel("Year", fontsize=20)
plt.ylabel("World Population (e^9)", fontsize=20)

# Set the font size of the number lables on the axes
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.savefig("python-linear-reg-custom.png")
